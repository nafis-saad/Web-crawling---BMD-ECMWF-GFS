# %% [markdown]
# <a href="https://colab.research.google.com/github/nafis-saad/Web-crawling---BMD-ECMWF-GFS/blob/main/Web_crawling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Requests

# %%
# !pip install requests
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import requests

url = 'https://realpython.github.io/fake-jobs/'

page = requests.get(url)
print(page.status_code)
print(page.url)
print(page.headers)
print(type(page.headers))
print(page.reason)
print(page.content)
print(page.text)
# Out:
# 200
# https://realpython.github.io/fake-jobs/
# {'Connection': 'keep-alive', 'Content-Length': '5721', 'Server': 'GitHub.com', 'Content-Type': 'text/html; charset=utf-8', 'permissions-policy': 'interest-cohort=()', 'Last-Modified': 'Mon, 12 Apr 2021 09:01:55 GMT', 'Access-Control-Allow-Origin': '*', 'ETag': 'W/"60740c83-197ed"', 'expires': 'Wed, 08 Jun 2022 12:11:03 GMT', 'Cache-Control': 'max-age=600', 'Content-Encoding': 'gzip', 'x-proxy-cache': 'MISS', 'X-GitHub-Request-Id': '6A74:6112:1CEE3A:BA33BB:62A08F7F', 'Accept-Ranges': 'bytes', 'Date': 'Wed, 08 Jun 2022 12:02:43 GMT', 'Via': '1.1 varnish', 'Age': '0', 'X-Served-By': 'cache-fty21371-FTY', 'X-Cache': 'MISS', 'X-Cache-Hits': '0', 'X-Timer': 'S1654689763.261243,VS0,VE20', 'Vary': 'Accept-Encoding', 'X-Fastly-Request-ID': 'adf437cb031e4eca2c52686ef14c3d562f116c2f'}
# <class 'requests.structures.CaseInsensitiveDict'>
# OK
# ...

# %% [markdown]
# Image Get and Processing

# %%
# !pip install pillow
import requests
from io import BytesIO
from PIL import Image


url = "https://images.pexels.com/photos/68147/waterfall-thac-dray-nur-buon-me-thuot-daklak-68147.jpeg?cs=srgb&dl=pexels-public-domain-pictures-68147.jpg&fm=jpg"

r = requests.get(url)

print(r.status_code)
image = Image.open(BytesIO(r.content))
print(image.size, image.format, image.mode)
path = "./Image." + image.format

try:
  image.save(path, image.format)
except IOError:
  print("Balsal")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install beautifulsoup4
# import requests
# from PIL import Image 
# from io import BytesIO
# from bs4 import BeautifulSoup


# search = input("Enter what you want to search")
# param = {'q': search}

# r = requests.get("https://www.bing.com/images/search", params = param)
# print(r.status_code)
# soup = BeautifulSoup(r.text, "html.parser")
# links = soup.find_all("a", {'class':"iusc"})

# for items in links:
#   imj_object = requests.get(items["href"])
#   title = items["href"].split("/")[-1]
#   img = Image.open(BytesIO(imj_object.content))
#   img.save("./Scrapped/" + title, img.format)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# API Calling

# %%
import requests
# Make an API call and store the response.
url = 'https://api.github.com/search/repositories?q=language:python&sort=stars'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")
# Store API response in a variable.
response_dict = r.json()
# Process results.
print(response_dict.keys())
